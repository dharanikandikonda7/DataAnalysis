# %% [markdown]
# ## Matplotlib - Python visualization libraray

# %% [markdown]
# ### 1.  What is Matplotlib?
#   Matplotlib is a python library for creating static animated and interactive visualizations.
#
# #### Why we need it?
#   It helps to understand trends , patterns and outliers.
#
# #### Where we use it?
# 1.Data Analysis
#
# 2.Machine learning(for plotting loss curves)
#
# 3.For Bussiness purposes(Analysing Market Trends, finance and scientific research).

# %% [markdown]
# ### 2. Import Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Line Plot

# %%
x = [1,2,3,4,5]
y = [10,20,25,30,40]
 
plt.plot(x, y,color="pink",marker="o")
plt.title("Line Plot Example",color="red")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# #### 2. Bar Plot

# %%
categories = ['A','B','C','D']
values = [10,15,7,12]
 
plt.bar(categories, values, color='green')
plt.title("Bar Plot Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# #### 3. Scatter Plot

# %%
x = [5,7,8,7,2,17,2,9,4,11]
y = [99,86,87,88,100,86,103,87,94,78]
 
plt.scatter(x, y, color='red', marker='*')
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# #### 4. Histogram

# %%
data = [22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]
 
plt.hist(data, bins=5, color='orange', edgecolor='black')
plt.title("Histogram Example")
plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### 5. Customized Plot

# %%
x = [1,2,3,4,5]
y = [2,3,5,7,11]
 
plt.plot(x, y, color='purple', linestyle='--', marker='o', label='Line 1')
plt.title("Customized Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
plt.show()

# %% [markdown]
# #### 6. Sub plot

# %%
x = [1,2,3,4,5]
y1 = [2,3,5,7,11]
y2 = [1,4,6,8,10]
 
plt.subplot(1,2,1)  # 1 row, 2 columns, plot 1
plt.plot(x, y1, color='blue')
plt.title("Plot 1")
 
plt.subplot(1,2,2)  # 1 row, 2 columns, plot 2
plt.plot(x, y2, color='red')
plt.title("Plot 2")
 
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Save plot

# %%
plt.plot(x, y1)
plt.title("Save Plot Example")
plt.savefig("my_plot.png")  # Saves in current directory
plt.show()

# %% [markdown]
# #### 7. Pie Chart

# %%
labels = ['Python', 'Java', 'C++', 'Ruby']
sizes = [215, 130, 245, 210]
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']
 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# #### * 8. Box Plot

# %%
data = [25, 30, 35, 35, 40, 45, 50, 55, 60]
plt.boxplot(data)
plt.title("Box Plot Example (Statistical Distribution)")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# #### 9. Violin Plot

# %%
import numpy as np
data = np.random.normal(0, 1, 100)
plt.violinplot(data)
plt.title("Violin Plot Example")
plt.show()

# %% [markdown]
# #### 10. Stem Plot

# %%
x = np.linspace(0, 2*np.pi, 10)
y = np.cos(x)
plt.stem(x, y)
plt.title("Stem Plot Example")
plt.show()

# %% [markdown]
# #### 11. Step Plot

# %%
# x = np.linspace(0, 2*np.pi, 10)
# y = np.cos(x)
# plt.step(x, y)
# plt.title("Step Plot Example")
# plt.show()

x = [1,2,3,4,5]
y = [2,3,5,6,8]
plt.step(x, y, where='mid', color='magenta')
plt.title("Step Plot Example")
plt.show()

# %% [markdown]
# #### 12. Area Plot

# %%
y = [2,4,6,8,10]
plt.fill_between(x, y, color='lightblue', alpha=0.6)
plt.title("Area Plot Example")
plt.show()

# %% [markdown]
# #### 13. Contour Plot

# %%
x = np.linspace(-3, 3, 30)
y = np.linspace(-3, 3, 30)
X, Y = np.meshgrid(x, y)
Z = np.sqrt(X**2 + Y**2)
 
plt.contour(X, Y, Z, cmap='plasma')
plt.title("Contour Plot Example")
plt.colorbar()
plt.show()

# %%
plt.contourf(X, Y, Z, cmap='viridis')
plt.title("Filled Contour Plot")
plt.colorbar()
plt.show()

# %% [markdown]
# #### 14. Polar Plot

# %%
theta = np.linspace(0, 2*np.pi, 100)
r = np.abs(np.sin(2*theta))
plt.polar(theta, r)
plt.title("Polar Plot Example")
plt.show()

# %% [markdown]
# #### 15. Error Bar Plot

# %%
x = np.arange(1,6)
y = np.random.randint(5,15,5)
errors = np.random.rand(5)
 
plt.errorbar(x, y, yerr=errors, fmt='o', ecolor='red', capsize=5)
plt.title("Error Bar Plot Example")
plt.show()

# %%
x = np.arange(1,6)
y = np.random.randint(5,15,5)
errors = np.random.rand(5)
 
plt.errorbar(x, y, xerr=errors, fmt='o', ecolor='red', capsize=5)
plt.title("Error Bar Plot Example")
plt.show()

# %% [markdown]
# #### 16. Horizontal Bar Plot

# %%
categories = ['A','B','C','D']
values = [10,15,7,12]
 
plt.barh(categories, values, color='orange')
plt.title("Horizontal Bar Plot")
plt.show()

# %% [markdown]
# #### 17. Stack plot

# %%
days = [1,2,3,4,5]
eating = [2,3,4,3,4]
sleeping = [8,7,8,6,7]
working = [8,9,7,8,8]
 
plt.stackplot(days, eating, sleeping, working, labels=['Eating','Sleeping','Working'])
plt.legend()
plt.title("Stack Plot Example")
plt.show()

# %% [markdown]
# #### 18. Hexbin plot

# %%
x = np.random.randn(1000)

y = np.random.randn(1000)

plt.hexbin(x, y, gridsize=25, cmap='Blues')

plt.colorbar()

plt.title("Hexbin Plot Example")

plt.show()

# %% [markdown]
# #### 19. 3D Surface Plot

# %%
from mpl_toolkits.mplot3d import Axes3D
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
X = np.linspace(-5, 5, 30)
Y = np.linspace(-5, 5, 30)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
ax.plot_surface(X, Y, Z, cmap='coolwarm')
ax.set_title("3D Surface Plot")
plt.show()

# %% [markdown]
# #### 20. 3D Line Plot

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
t = np.linspace(0, 10, 100)
x = np.sin(t)
y = np.cos(t)
z = t
 
ax.plot3D(x, y, z, 'purple')
ax.set_title("3D Line Plot")
plt.show()

# %% [markdown]
# #### 21. 3D Scatter Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)
 
ax.scatter(x, y, z, color='red', marker='o')
ax.set_title("3D Scatter Plot")
plt.show()

# %% [markdown]
# #### 22. 3D Wireframe Plot

# %%
x = np.linspace(-5, 5, 30)
y = np.linspace(-5, 5, 30)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X, Y, Z, color='green')
ax.set_title("3D Wireframe Plot")
plt.show()

# %% [markdown]
# #### 23. 3D Contour Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
X = np.linspace(-5, 5, 50)
Y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
ax.contour3D(X, Y, Z, 50, cmap='plasma')
ax.set_title("3D Contour Plot")
plt.show()

# %% [markdown]
# #### 24. 3D Bar Plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
x = [1, 2, 3, 4, 5]
y = [2, 3, 4, 5, 6]
z = np.zeros(5)
dx = np.ones(5)
dy = np.ones(5)
dz = [5, 2, 7, 3, 6]
 
ax.bar3d(x, y, z, dx, dy, dz, color='teal')
ax.set_title("3D Bar Plot")
plt.show()

# %% [markdown]
# #### 25. 3D Surface with Colormap

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
X = np.linspace(-5, 5, 50)
Y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = np.cos(np.sqrt(X**2 + Y**2))
 
surf = ax.plot_surface(X, Y, Z, cmap='coolwarm', edgecolor='none')
fig.colorbar(surf)
ax.set_title("3D Surface with Colormap")
plt.show()

# %% [markdown]
# #### 26. 3D Sphere Surface

# %%
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, color='skyblue')
ax.set_title("3D Sphere Surface")
plt.show()

# %% [markdown]
# #### 27. 3D Surface + Wireframe

# %%
X = np.linspace(-5, 5, 30)
Y = np.linspace(-5, 5, 30)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, alpha=0.7, cmap='viridis')
ax.plot_wireframe(X, Y, Z, color='black', linewidth=0.5)
ax.set_title("3D Surface + Wireframe")
plt.show()

# %% [markdown]
# #### 28. 3D Contour Projection on Planes

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
 
x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
 
ax.contour(X, Y, Z, zdir='z', offset=-2, cmap='coolwarm')
ax.contour(X, Y, Z, zdir='x', offset=-5, cmap='coolwarm')
ax.contour(X, Y, Z, zdir='y', offset=5, cmap='coolwarm')
 
ax.set_title("3D Contour Projection on Planes")
plt.show()

# %% [markdown]
# #### => Hands-On Exercise

# %%
# 1.Create a line plot of student marks across 5 exams.
 
data=[20,30,50,20,60]
sub=["eng","Hin","tel","ai","science"]

plt.plot(data,sub,marker="o")
plt.title("Line Plot")
plt.xlabel("marks")
plt.ylabel("subject")
plt.show()

# %%
# 2.Plot a bar chart of sales of 4 products.

year=[2020,2021,2022,2023]
sales=[100,50,20,150]

plt.bar(year,sales,color="red")
plt.title("Bar Plot")
plt.ylabel("sales")
plt.xlabel("Years")
plt.show()

# %%
# 3.Make a scatter plot of Age vs Salary.

age=[19,20,24,50]
sal=[20000,19000,25000,100000]

plt.scatter(age,sal,color="red")
plt.title("Scatter Plot")
plt.xlabel("age")
plt.ylabel("salary")
plt.show()

# %%
# 4.Draw a histogram of marks scored by students in a class.
 
marks=[80,90,75,65]
plt.hist(marks, bins=5, color='orange', edgecolor='black')
plt.title("Histogram")
plt.xlabel("marks")
plt.ylabel("students")
plt.show()

# %%
# 5.Customize a plot with different colors, markers, and line styles.

data=[10,20,30,40,45]
y=[1,2,3,4,5]
plt.plot(data,y,color='yellow',marker='o',linestyle='--')
# plt.legend()
plt.show()

# %%
# 6.Create two subplots: Line plot and bar plot side by side.

x=[1,2,3,4]
y=[3,4,2,5]
z=[3,2,4,5]
plt.subplot(1,3,1)
plt.plot(x,y,color="red")
plt.title("plot-1")


plt.subplot(1,2,2)
plt.plot(x,y,color="black")
plt.title("plot-2")



plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
